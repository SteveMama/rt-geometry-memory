# %% [markdown]
# # Paper 3 Harm Predictor Runner
#
# Use this notebook after a positive Gate 1 oracle result to train the harm predictor and run the Gate 3 comparison.

# %%
# %cd /content
# !git clone https://github.com/pranavraj575/rt-geometry-memory.git
# %cd /content/rt-geometry-memory
# !bash scripts/colab_setup.sh

# %%
RUN_NAME = "paper3_harm_predictor_smoke"
INPUT_PATH = "/content/rt-geometry-memory/benchmarks/msc_valid_normalized.jsonl"
ORACLE_STUDY_DIR = "results/paper3/harm_oracle/paper3_oracle_harm_smoke"
MODELS = "qwen25_05b"
BUDGETS = "0.20,0.35"
LIMIT = 8
STRIDE = 4
MAX_TARGETS = 8

# %%
# !bash scripts/run_paper3_harm_predictor_probe.sh "$RUN_NAME" "$INPUT_PATH" "$ORACLE_STUDY_DIR" "$MODELS" "$BUDGETS" "$LIMIT" "$STRIDE" "$MAX_TARGETS"
