# %% [markdown]
# # Paper 3 Semantic-First Query-Geometry Runner
#
# Use this notebook to run the Gate 2 semantic-first hybrid comparison after the oracle report is available.

# %%
# %cd /content
# !git clone https://github.com/pranavraj575/rt-geometry-memory.git
# %cd /content/rt-geometry-memory
# !bash scripts/colab_setup.sh

# %%
RUN_NAME = "paper3_semantic_query_geom_smoke"
INPUT_PATH = "/content/rt-geometry-memory/benchmarks/msc_valid_normalized.jsonl"
MODELS = "qwen25_05b"
BUDGETS = "0.20,0.35,0.50"
LIMIT = 8
STRIDE = 4
MAX_TARGETS = 8

# %%
# !bash scripts/run_paper3_semantic_query_geom_probe.sh "$RUN_NAME" "$INPUT_PATH" "$MODELS" "$BUDGETS" "$LIMIT" "$STRIDE" "$MAX_TARGETS"
