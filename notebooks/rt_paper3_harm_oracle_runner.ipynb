# %% [markdown]
# # Paper 3 Oracle Harm Runner
#
# Use this notebook to run the Gate 1 oracle-harm headroom probe on a normalized benchmark JSONL.

# %%
# %cd /content
# !git clone https://github.com/pranavraj575/rt-geometry-memory.git
# %cd /content/rt-geometry-memory
# !bash scripts/colab_setup.sh

# %%
RUN_NAME = "paper3_oracle_harm_smoke"
BENCHMARK_NAME = "msc_valid"
INPUT_PATH = "/content/rt-geometry-memory/benchmarks/msc_valid_normalized.jsonl"
MODELS = "qwen25_05b"
BUDGETS = "0.20,0.35"
LIMIT = 8
STRIDE = 4
MAX_TARGETS = 8

# %%
# !bash scripts/run_paper3_harm_oracle_probe.sh "$RUN_NAME" "$BENCHMARK_NAME" "$INPUT_PATH" "$MODELS" "$BUDGETS" "$LIMIT" "$STRIDE" "$MAX_TARGETS"
